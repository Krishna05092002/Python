# %%
def check_amount(amount):
    if amount >0:
        print("postive amount -", "Deposit")
        trans="postive amount", "Deposit"
    elif amount <0:
        print("Negative amount -","Withdrawal")
        trans= "Negative amount","Withdrawal"
    else:
        print("Zero amount -" ,"No Transaction")
        trans="Zero amount" ,"No Transaction"
    return trans
value = float(input("Enter Transaction Amount:"))
print(check_amount(value))
# Out:
# Enter Transaction Amount: 2000
# postive amount - Deposit
# ('postive amount', 'Deposit')

# %%
check_amount(value)
# Out:
# postive amount - Deposit
# ('postive amount', 'Deposit')

# %%
trans=check_amount(value)
# Out:
# postive amount - Deposit

# %%
def Digits_of_Number(number):
    number= abs(number)
    total =0
    if number>0:
        digit = number%10
        total += digit
        number //= 10
    return total
num= int(input("Enter PassCode:"))
print(Digits_of_Number(num))
# Out:
# Enter PassCode: 2002
# 2

# %%
def Reverse_number(num):
    num=int(input("Enter a Id Number:"))
    num_str = str(num)
    reversed_str = num_str[::-1]
    reversed_num= int(reversed_str)
    return reversed_num
print("Reversed Id:",Reverse_number(num))
# Out:
# Enter a Id Number: 6789
# Reversed Id: 9876

# %%
num = int(input("Enter a number: "))
if num <2:
    print ("Not Prime")
else:
    print("is prime")
    for i in range(2,int(num**0.5) +1):
        if num %1 == 0:
            print("Not Prime")
# Out:
# Enter a number:  3
# is prime

# %%
def factorial(num):
    result = 1
    for i in range(1, num + 1):
        result *= i
    return result
number = int(input("Enter a Number:"))
print("Factorial:", factorial(number))
# Out:
# Enter a Number: 5
# Factorial: 120

# %%
num = int(input("Enter a Number:"))
digits = len(str(num))
sum_val = 0

for digit in str(num):
    sum_val += int(digit)**digits
    
    if sum_val == num:
        print("Armstrong Num is:",num)
    else:
        print("Not Armstrong Num is :" , num )
# Out:
# Enter a Number: 12
# Not Armstrong Num is : 12
# Not Armstrong Num is : 12

# %%
string = input ("Enter a String :")
if len(string )< 1 :
    print(string)
else:
    modified = string[-1] + string[1:-1] + string
    print(modified)
# Out:
# Enter a String : greekworld
# dreekworlgreekworld

# %%
num = int(input("Enter a Decimal Number:"))
binary = ""
temp = num 
if num == 0:
    binary = "0"
else:
    while num > 0:
        remainder = num % 2
        binary += str( remainder)
        num //=2
binary = binary [:: - 1]
print("Binary of", temp , "is", binary )
# Out:
# Enter a Decimal Number: 15
# Binary of 15 is 1111

# %%
sentence = input ("Enter a Senctence:")
words = sentence.split()
longest = ""
for sentence in words:
    if len(sentence)> len(longest):
        longest = sentence

print("The longest word is:" , longest)
# Out:
# Enter a Senctence: Journey is happiness
# The longest word is: happiness

# %%
name1 = input("Enter first word :")
name2 = input("Enter second word:")

name1 = name1.replace(" ","").lower()
name2=  name2.replace(" ","").lower()

if sorted(name1) == sorted(name2):
    print("Anagram")
else:
    print("Not an Anagram")
# Out:
# Enter first word : krishna
# Enter second word: dharma
# Not an Anagram
