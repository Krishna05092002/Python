# %%
user = input("Enter a number:")
if user.isdigit():
    number = int(user)
else:
    print("invalid input ! Please enter a valid integer.") 

print("You entered:", number)
# Out:
# Enter a number: 1
# You entered: 1

# %%
numbers = [1,2,2,3,4,2,5,3,3]
frequency ={}
for num in numbers:
    if num in frequency:
        frequency[num] +=1
    else:
        frequency[num] =1
most_frequent = max(frequency , key= frequency.get)
print("Most Frequent number is:", most_frequent)
# Out:
# Most Frequent number is: 2

# %%
str1 = input("Enter first String :")
str2 = input("Enter Second String :")
str1 = str1.replace(" ", " ").lower()
str2 = str2.replace(" ", " ").lower()
if sorted(str1) == sorted(str2):
    print("They are Anagrams")
else:
    print("They are not Anagrams")
# Out:
# Enter first String : Greekworld
# Enter Second String : Helloworld
# They are not Anagrams

# %%
text = input ("Enter a String:")
vowels = set("aeiouAEIOU")
count = 0
for ch in text :
    if ch in vowels:
        count +=1

print("Total vowels:",count)
# Out:
# Enter a String: hope AI
# Total vowels: 4

# %%
sentence = input("Enter a Sentence:")
words = sentence.split()
words.reverse()
reversed_sentence = " ".join(words)
print("Reversed Sentence:", reversed_sentence)
# Out:
# Enter a Sentence: Artificial Intelligence
# Reversed Sentence: Intelligence Artificial

# %%
numbers = [ 1,2,4,5]
n = len(numbers) + 1 
expected_sum = n * (n+1) // 2
actual_sum = sum(numbers)
missing_number = expected_sum - actual_sum
print("Missing number is:",missing_number)
# Out:
# Missing number is: 3

# %%
balance = float(input("Enter your account balance:"))
withdraw = float(input("Enter Withdrawal Amount:"))
if withdraw <= balance:
    balance -= withdraw

    print("Withdrawal Successful!")
    print("Remaining balance:", balance)

else:
    print("Error : Insufficient funds.")
# Out:
# Enter your account balance: 2000
# Enter Withdrawal Amount: 1500
# Withdrawal Successful!
# Remaining balance: 500.0

# %%
values = [ 1, 2, 3, 4, 2]

unique_set = set()
duplicate_found = False

for v in values:
    if v in unique_set:
        duplicate_found = True
        break
    else:
        unique_set.add(v)

print(duplicate_found)
# Out:
# True

# %%
num = input("Enter a number:")
digits = list(num)
total = 0
for d in digits:
    total += int(d)

print("Sum of digits:", total)
# Out:
# Enter a number: 284
# Sum of digits: 14

# %%
sentence = input("Enter a Sentence:").lower()
letters = set()
if len(letters) == 26:
    print("It  is a pangram")
else:
    print("It is not a pangram")
# Out:
# Enter a Sentence: Hello Welcome Hope AI is Best Online Tutorial
# It is not a pangram
