# %%
from ClassAssignment1 import Assignmentfunctions

# %%
Assignmentfunctions.subfieldinAI()
# Out:
# Sub- Fields in AI are: AI and DS
# Machine learning
# Neural  network
# Vision
# Robotics
# Speech processing
# Natural language processing

# %%
Assignmentfunctions.oddeven()
# Out:
# Enter a Num: 52452
# Even number
# 'Even number'

# %%
Assignmentfunctions.Elegible()
# Out:
# Your Gender: Male
# Your Age: 20
# Not Eligible

# %%
Assignmentfunctions.percentage()
# Out:
# Subject1: 98
# Subject2: 87
# Subject3: 95
# Subject4: 95
# Subject5: 93
# Total: 468
# percentage: 93.60000000000001

# %%
Assignmentfunctions.triangle()
# Out:
# Height: 32
# Breadth: 34
# Area formula: (Height*Breadth)/2
# Area of Triangle:  544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle:  10
